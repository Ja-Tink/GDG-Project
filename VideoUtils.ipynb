# %%
import cv2
from matplotlib import pyplot as plt

# %%
video_path = 'Videos/NYU Tour.mp4'

# %%
'''
Function to get every <frame_interval>th frame from <video_path>
'''
def extractFrames(video_path, frame_interval):
    cap = cv2.VideoCapture(video_path)

    outlist = []
    
    # get total number of frames
    totalFrames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    
    frame_indices = [index for index in range(int(totalFrames)) if index % frame_interval == 0]
    
    for frame_number in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
        ret, frame = cap.read()

        outlist.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        '''
        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB), interpolation='nearest')
        plt.show()
        '''
    
    cap.release()

    return outlist

# %%
frameList = extractFrames(video_path, 1000)

for i in frameList:
    plt.imshow(i, interpolation = 'nearest')
    plt.show()
